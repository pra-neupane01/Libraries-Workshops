# %%
import cv2
cap = cv2.VideoCapture(r"C:\Users\neupa\Libraries-Workshops\Open CV\Tasks\Resources\video.mp4")
counter = 0

while cap.isOpened():
    r, frame = cap.read()
    if r == True:
        cv2.imshow("window",frame)
        filename = C:\\Users\\neupa\\Libraries-Workshops\\Open CV\\Tasks\\Extracted Image\\ + str(counter) + ".png"
        cv2.imwrite(filename,frame)
        counter = counter + 1

        if cv2.waitKey(25) & Oxff == ord("p"):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()

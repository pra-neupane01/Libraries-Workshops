# %%
import cv2 
image1 = cv2.imread(r"C:\Users\neupa\Libraries-Workshops\Open CV\Tutorials\Images\sharbhari.jpg")
image2 = cv2.imread(r"C:\Users\neupa\Libraries-Workshops\Open CV\Tutorials\Images\SRK.jpg")
image1 = cv2.resize(image1,(300,300))
image2 = cv2.resize(image2,(300,300))
new_img = cv2.addWeighted(image1,0.6,image2,0.3,1)
#new_img = cv2.subtract(image2, image1)
cv2.imshow("my window",new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
image = cv2.imread(r"C:\Users\neupa\Libraries-Workshops\Open CV\Tasks\Resources\SRK.jpg")
image = cv2.resize(image,(800,600))

white_image = np.ones((600,600,3),np.uint8)* 255
black_image = np.zeros((600,600,3),np.uint8)

cv2.imshow("window",black_image)
cv2.imshow("window2",white_image)

cv2.waitKey(0)
cv2.destroyAllWindows()

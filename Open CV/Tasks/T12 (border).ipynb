# %%
import cv2
import numpy as np

image = cv2.imread(r"C:\Users\neupa\Libraries-Workshops\Open CV\Tasks\Images\sharbhari.jpg")
image = cv2.resize(image, (400,500))

bordered_image = cv2.copyMakeBorder(image,10,10,10,10,cv2.BORDER_CONSTANT)
cv2.imshow("window",bordered_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import os

# %%
list_name = os.listdir(r"C:\Users\neupa\Open CV\T1\Images")

for name in list_name:
    path = "C:\\Users\\neupa\\Open CV\\T1\\Images"
    img_name = path + "\\" + name
    img = cv2.imread(img_name)
    img = cv2.resize(img, (200,200))
    cv2.imshow("my window",img)
    cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Skipped (not an image or unreadable): .ipynb_checkpoints
# Skipped (not an image or unreadable): T1 (read and show multiple image).ipynb
# Skipped (not an image or unreadable): Untitled.ipynb
# Skipped (not an image or unreadable): When the protector sits in stillness, and the destroyer rises in form — the cave becomes a temple, the fire becomes light, and devotion becomes eternal_ Ganpati seated beneath Mahadev’s symbol, glowing in cosmic ha.jpg

# %%
import cv2
image = cv2.imread(r"C:\Users\neupa\Libraries-Workshops\Open CV\Tasks\Resources\SRK.jpg")
image = cv2.resize(image,(800,600))
# image[y1:y2, x1:x2]

crop_image = image[160:200, 370:470
    ]
cv2.imshow("window1",crop_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

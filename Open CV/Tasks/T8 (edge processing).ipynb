# %%
import cv2 
image1 = cv2.imread(r"C:\Users\neupa\Libraries-Workshops\Open CV\Tutorials\Images\sharbhari.jpg")
image1 = cv2.resize(image1,(300,300))
new_img = cv2.Canny(image1,50,200, apertureSize = 5, L2gradient= False)
cv2.imshow("window1",image1)
cv2.imshow("window2",new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 3
#       1 import cv2
#       2 image1 = cv2.imread(r"C:\Users\neupa\Libraries-Workshops\Open CV\Tutorials\Images\sharbhari.jpg")
# ----> 3 image1 = cv2.resize(image1,(300,300))
#       4 new_img = cv2.Canny(image1,50,200, apertureSize = 5, L2gradient= False)
#       5 cv2.imshow("window1",image1)
#       6 cv2.imshow("window2",new_img)
#
# error: OpenCV(5.0.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4217: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

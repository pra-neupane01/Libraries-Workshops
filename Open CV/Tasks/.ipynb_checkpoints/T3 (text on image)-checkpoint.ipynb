# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\neupa\Open CV\T1\Images\ganesh.jpg")
cv2.resize(img, (1200,400))
cv2.putText(img,"Jay Ganesh",(80,100),cv2.FONT_HERSHEY_COMPLEX,2,(0,255,0),2,cv2.LINE_8,False)
cv2.imshow("My window",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
image = cv2.imread(r"C:\Users\neupa\Libraries-Workshops\Open CV\Tasks\Resources\SRK.jpg")
new_image = cv2.cvtColor(image,cv2.COLOR_BGR2XYZ )
cv2.imshow("window",image)
cv2.imshow("window1",new_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

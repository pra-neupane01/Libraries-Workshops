# %%
import cv2
image = cv2.imread(r"C:\Users\neupa\Libraries-Workshops\Open CV\Tasks\Images\sharbhari.jpg")
re_image = cv2.resize(image, (400,500))
m = cv2.getRotationMatrix2D((200,250),90,1)
cv2.warpAffine(re_image,m,(400,500))

cv2.imshow("window", re_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
